# %%
# Cell 1: Hello Biology World
print("Welcome to HCC Synthetic Lethality Project - Day 1")

# Cell 2: Store real biological data
gene_name = "POLQ"                    # top SL gene from your manuscript
patient_id = "TCGA-LIHC-01A"          # real TCGA sample
expression_value = 8.45               # log2(TPM) of POLQ in HCC
is_hrd = True                         # boolean flag for HRD-like subtype

print("Gene:", gene_name)
print("Patient:", patient_id)
print("POLQ expression:", expression_value)
print("HRD status:", is_hrd)
# Cell 3: Simple calculation you will use later
normal_expression = 4.2
tumor_expression = 8.45
log2_fold_change = tumor_expression - normal_expression
print("POLQ log2FC in HCC =", log2_fold_change)   # exactly like manuscript
# Out:
# Welcome to HCC Synthetic Lethality Project - Day 1
# Gene: POLQ
# Patient: TCGA-LIHC-01A
# POLQ expression: 8.45
# HRD status: True
# POLQ log2FC in HCC = 4.249999999999999

# %%
print("anwesha")
# Out:
# anwesha

# %%
# Cell 4: Comments are your lab notebook
# TODO Phase 1: calculate mutation co-occurrence for TP53 and MDM4
# TODO Phase 2: build GAT graph with STRING PPI edges

# %%
#cell 5: Biological example 1
gene_name1= "POLQ"
gene_type= "Cancer"
print("The ",gene_name1," is of gene type ",gene_type)
# Out:
# The  POLQ  is of gene type  Cancer

# %%
#cell 6:biological example 2
gene_name2= "CTNNB1"
p_value = 0.05
print("The significance value of ",gene_name2," is: ",p_value)
# Out:
# The significance value of  CTNNB1  is:  0.05

# %%
#cell 7: Biological example 3
gene_name3= "TERT"
cancer_name= "hepatocellular carcinoma"
print(gene_name3," belong to the cancer type ",cancer_name)
# Out:
# TERT  belong to the cancer type  hepatocellular carcinoma

# %%
#print() is used to print any line
#conda create -n hcc-sl is used to create a new environment named hcc-sl
#gene="BRCA1"
#No. Since python is case sensitive
#it will print 4.25
# a #comment will not be included during runnig the code, but the string will be run during the code
# because it is user-friendly
# command to activate the environment is conda activate
# "Phase 4: train cVAE here"
# HCC-SL-Project

# %%
"I have installed Python and created my HCC-SL-Project repo. Ready for Day 2."
